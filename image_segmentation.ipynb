# %% [markdown]
# ### Image segmentation using Pytorch

# %% [markdown]
# #### Dataset obtention and preparation

# %%
from torchvision.datasets import Flowers102, OxfordIIITPet

train_dataset = OxfordIIITPet(root='./data/o_pets/train', download=True, split='trainval', target_types='segmentation')
# Out:
# ...
#   0%|          | 0/791918971 [00:00<?, ?it/s]
# Extracting data/o_pets/train/oxford-iiit-pet/images.tar.gz to data/o_pets/train/oxford-iiit-pet
# ...
#   0%|          | 0/19173078 [00:00<?, ?it/s]
# Extracting data/o_pets/train/oxford-iiit-pet/annotations.tar.gz to data/o_pets/train/oxford-iiit-pet

# %%
img, label_masks = train_dataset[0]

#show image and label masks
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(img)

# %%
plt.imshow(label_masks)
